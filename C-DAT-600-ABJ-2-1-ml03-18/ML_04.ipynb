# %% [markdown]
# # 1 - create a BaggingClassifier model from Scikit-learn combining KNeighborsClassifier, OneVsRestClassifier and DecisionTreeClassifier

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# Create the BaggingClassifier with specified parameters
bagging_clf = BaggingClassifier(
    base_estimator=DecisionTreeClassifier(random_state=42),
    n_estimators=10,
    max_samples=0.8,
    max_features=0.7,
    random_state=42
)

# Fit the model using the training data
bagging_clf.fit(X_train, y_train)   

# Make predictions on the test set
y_pred = bagging_clf.predict(X_test)

# Evaluate the model's accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"BaggingClassifier Accuracy: {accuracy}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       8 from sklearn.tree import DecisionTreeClassifier
#      10 # Create the BaggingClassifier with specified parameters
# ---> 11 bagging_clf = BaggingClassifier(
#      12     base_estimator=DecisionTreeClassifier(random_state=42),
#      13     n_estimators=10,
#      14     max_samples=0.8,
#      15     max_features=0.7,
#      16     random_state=42
#      17 )
#      19 # Fit the model using the training data
#      20 bagging_clf.fit(X_train, y_train)
#
# TypeError: BaggingClassifier.__init__() got an unexpected keyword argument 'base_estimator'
